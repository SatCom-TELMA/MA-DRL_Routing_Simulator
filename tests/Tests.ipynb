# %% [markdown]
# # Test Notebook

# %%
from SimulationRL import *

populationMap   = 'Population Map/gpw_v4_population_count_rev11_2020_15_min.tif'
inputPath       = './'
outputPathTest  = './test_output/'
env             = simpy.Environment()
inputParams     = pd.read_csv(inputPath + "inputRL.csv")
locations       = inputParams['Locations'].copy()

# %%
earth1, graph1, bottleneck1, bottleneck2 = initialize(env, populationMap, inputPath + 'Gateways.csv', rKM, inputParams, movementTime, locations)
# Out:
# c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\matplotlib\animation.py:887: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you have outputted the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
# Using Kepler constellation design
# total divisions in x = 1440
#  total divisions in y = 720
#  total cells = 1036800
#  window of operation (longitudes) = (0, 1440)
#  window of operation (latitudes) = (0, 720)
#
# Finding cells within coverage area of GT 18 of 18
# Time taken to find cells that are within range of all GTs: 8.018071413040161 seconds
# Time taken to add cell information to all GTs: 0.09989714622497559 seconds
#
# State Space:
#  ('UpLinked Up', 'UpLinked Down', 'UpLinked Right', 'UpLinked Left', 'Up Latitude', 'Up Longitude', 'DownLinked Up', 'DownLinked Down', 'DownLinked Right', 'DownLinked Left', 'Down Latitude', 'Down Longitude', 'RightLinked Up', 'RightLinked Down', 'RightLinked Right', 'RightLinked Left', 'Right Latitude', 'Right Longitude', 'LeftLinked Up', 'LeftLinked Down', 'LeftLinked Right', 'LeftLinked Left', 'Left Latitude', 'Left Longitude', 'Actual latitude', 'Actual longitude', 'Destination latitude', 'Destination longitude')
# Action Space:
#  ('U', 'D', 'R', 'L')
# ----------------------------------
# Neural Network Created!!!
# ----------------------------------
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 32)                928
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dense_5 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 2,116
# Trainable params: 2,116
# Non-trainable params: 0
# _________________________________________________________________
# Saving hyperparams at: ./Results/latency Test/Deep Q-Learning_1.0s_[10]_Del_[20]_w1_[20]_w2_[2]_GTs/

# %%
plotShortestPath(earth1, pathBlocks[1][-1].path, outputPath)

# %%
g = earth1.gateways[0].graph
shortestPath = nx.shortest_path(g, 'Malaga, Spain', 'Los Angeles, California, US', weight = 'slant_range')    # computes the shortest path [dataRate, slant_range, hops]

plotShortestPath(earth1, shortestPath, outputPathTest)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\IPython\core\interactiveshell.py", line 3378, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\flc\AppData\Local\Temp\ipykernel_4724\3222112937.py", line 4, in <module>
#     plotShortestPath(earth1, shortestPath, outputPathTest)
#   File "c:\Users\flc\workspace\Q-Learning\SimulationRL.py", line 4095, in plotShortestPath
#   File "c:\Users\flc\workspace\Q-Learning\SimulationRL.py", line 2976, in plotMap
#     yValues = []
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\IPython\core\interactiveshell.py", line 1997, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\IPython\core\ultratb.py", line 1112, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\IPython\core\ultratb.py", line 1006, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\IPython\core\ultratb.py", line 859, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\IPython\core\ultratb.py", line 812, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\IPython\core\ultratb.py", line 730, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\stack_data\core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\stack_data\core.py", line 660, in executing_piece
#     return only(
#   File "c:\Users\flc\anaconda3\envs\SatNEx\lib\site-packages\executing\executing.py", line 167, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
print(dir(earth1))
g = earth1.gateways[0].graph
# Get a list of nodes
print("Nodes:", g.nodes())

# Get a list of edges
print("Edges:", g.edges())

print(type(g))


# for node, data in g.nodes(data=True):
#     for key, value in data.items():
#         # Convert non-serializable attributes to strings (or any other supported type)
#         if not isinstance(value, (str, int, float, bool)):
#             data[key] = str(value)  # or any other method of serialization

# for u, v, data in g.edges(data=True):
#     for key, value in data.items():
#         # Convert non-serializable attributes to strings
#         if not isinstance(value, (str, int, float, bool)):
#             data[key] = str(value)  # or any other method of serialization

# # Now write the graph

# nx.write_graphml(g, outputPathTest + "g.graphml")

# %%
# Drawing the graph
plt.figure(figsize=(12, 8))
# nx.draw(g, with_labels=True, node_color='lightblue', font_weight='bold', node_size=700)
# plt.title('Graph Representation')
# plt.show()
# for edge in g.edges(data=True):
#     print(edge)

# Drawing the graph using the slant range as the link distance
plt.figure(figsize=(14, 10))

# Positions for all nodes
pos = nx.spring_layout(g)  # This may not represent physical positions, as those are not known

# Edges are drawn with width proportional to the weight of the edge
edges, weights = zip(*nx.get_edge_attributes(g, 'slant_range').items())

# Normalize the weights to use for edge width (for better visualization)
max_weight = max(weights)
min_weight = min(weights)
weights = [((w - min_weight) / (max_weight - min_weight) * 5) + 0.1 for w in weights]  # +0.1 to avoid line width 0

nx.draw(g, pos, node_color='lightblue', edgelist=edges, edge_color=weights, width=weights, with_labels=True, node_size=700)

plt.title('Graph with Slant Range as Link Distance')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation
import networkx as nx

# Load your graph g
# g = nx.read_graphml('your_graph.graphml')  # You would uncomment this line and replace with your file path

# Extract node positions with checks for missing data
pos = {}
for node, data in g.nodes(data=True):
    lon = data.get('longitude', None)
    lat = data.get('latitude', None)
    if lon is not None and lat is not None:
        pos[node] = (float(lon), float(lat))

# Initialize figure and 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Draw nodes
for node, (lon, lat) in pos.items():
    ax.scatter(lon, lat, 0, color='red' if 'satellite' in node else 'blue', marker='o' if 'satellite' in node else 'x', s=50)

# Draw edges with checks for missing node positions
for edge in g.edges():
    if edge[0] in pos and edge[1] in pos:
        lon_start, lat_start = pos[edge[0]]
        lon_end, lat_end = pos[edge[1]]
        ax.plot([lon_start, lon_end], [lat_start, lat_end], [0, 0], color='gray')

# Set labels and title
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_zlabel('Altitude')
ax.set_title('Animated 3D Graph')

# Animation update function
def update(num, ax, fig):
    ax.view_init(elev=10, azim=num)

# Create animation
ani = FuncAnimation(fig, update, frames=range(0, 360, 2), interval=50, fargs=(ax, fig))

# Display the plot
plt.show()

# To save the animation, use the following line:
# ani.save('animation.mp4', writer='ffmpeg', fps=30)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation
import networkx as nx

# Load your graph g
# g = nx.read_graphml('your_graph.graphml')  # You would uncomment this line and replace with your file path

# Diagnostic print to check if nodes have 'latitude' and 'longitude' attributes
print("Checking for 'latitude' and 'longitude' in nodes...")
for node, data in g.nodes(data=True):
    if 'latitude' not in data or 'longitude' not in data:
        print(f"Node {node} is missing 'latitude' or 'longitude' attributes")

# Extract node positions with checks for missing data
pos = {}
for node, data in g.nodes(data=True):
    lon = data.get('longitude', None)
    lat = data.get('latitude', None)
    if lon is not None and lat is not None:
        pos[node] = (float(lon), float(lat))

# Initialize figure and 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Draw nodes
for node, (lon, lat) in pos.items():
    ax.scatter(lon, lat, 0, color='red', zorder=5)

# Draw edges with checks for missing node positions
for edge in g.edges():
    if edge[0] in pos and edge[1] in pos:
        lon_start, lat_start = pos[edge[0]]
        lon_end, lat_end = pos[edge[1]]
        ax.plot([lon_start, lon_end], [lat_start, lat_end], 0, color='gray', zorder=4)

# Set labels and title
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_zlabel('Altitude')
ax.set_title('Animated 3D Graph')

# Animation update function
def update(num, ax, fig):
    ax.view_init(elev=10, azim=num)

# Create animation
ani = FuncAnimation(fig, update, frames=range(0, 360, 2), interval=50, fargs=(ax, fig))

# Display the plot
plt.show()

# To save the animation, use the following line:
# ani.save('animation.mp4', writer='ffmpeg', fps=30)

# %%
for node, data in g.nodes(data=True):
    if 'latitude' not in data or 'longitude' not in data:
        # print(dir(node))
        try:
            print((data['sat']))
        except KeyError:
            print((data['GT']))
# Out:
# ID = 0_0
#  orbital plane= 0, index in plane= 0, h=600000.00
#  pos r = 6978000.00, pos theta = 0.00, pos phi = 0.00,
#  pos x= 0.00, pos y= -1043457.63, pos z= 6899542.03
#  inclination = -8.60
#  polar angle = 0.00
#  latitude = 81.40
#  longitude = -90.00
#
# ID = 0_1
#  orbital plane= 0, index in plane= 1, h=600000.00
#  pos r = 6978000.00, pos theta = 0.31, pos phi = 0.00,
#  pos x= 2156320.59, pos y= -992387.18, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 18.00
#  latitude = 70.11
#  longitude = -24.71
#
# ID = 0_2
#  orbital plane= 0, index in plane= 2, h=600000.00
#  pos r = 6978000.00, pos theta = 0.63, pos phi = 0.00,
#  pos x= 4101565.49, pos y= -844174.95, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 36.00
#  latitude = 53.12
#  longitude = -11.63
#
# ID = 0_3
#  orbital plane= 0, index in plane= 3, h=600000.00
#  pos r = 6978000.00, pos theta = 0.94, pos phi = 0.00,
#  pos x= 5645320.59, pos y= -613329.00, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 54.00
#  latitude = 35.53
#  longitude = -6.20
#
# ID = 0_4
#  orbital plane= 0, index in plane= 4, h=600000.00
#  pos r = 6978000.00, pos theta = 1.26, pos phi = 0.00,
#  pos x= 6636472.37, pos y= -322446.14, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 72.00
#  latitude = 17.79
#  longitude = -2.78
#
# ID = 0_5
#  orbital plane= 0, index in plane= 5, h=600000.00
#  pos r = 6978000.00, pos theta = 1.57, pos phi = 0.00,
#  pos x= 6978000.00, pos y= -0.00, pos z= 0.00
#  inclination = -8.60
#  polar angle = 90.00
#  latitude = 0.00
#  longitude = -0.00
#
# ID = 0_6
#  orbital plane= 0, index in plane= 6, h=600000.00
#  pos r = 6978000.00, pos theta = 1.88, pos phi = 0.00,
#  pos x= 6636472.37, pos y= 322446.14, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 108.00
#  latitude = -17.79
#  longitude = 2.78
#
# ID = 0_7
#  orbital plane= 0, index in plane= 7, h=600000.00
#  pos r = 6978000.00, pos theta = 2.20, pos phi = 0.00,
#  pos x= 5645320.59, pos y= 613329.00, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 126.00
#  latitude = -35.53
#  longitude = 6.20
#
# ID = 0_8
#  orbital plane= 0, index in plane= 8, h=600000.00
#  pos r = 6978000.00, pos theta = 2.51, pos phi = 0.00,
#  pos x= 4101565.49, pos y= 844174.95, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 144.00
#  latitude = -53.12
#  longitude = 11.63
#
# ID = 0_9
#  orbital plane= 0, index in plane= 9, h=600000.00
#  pos r = 6978000.00, pos theta = 2.83, pos phi = 0.00,
#  pos x= 2156320.59, pos y= 992387.18, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 162.00
#  latitude = -70.11
#  longitude = 24.71
#
# ID = 0_10
#  orbital plane= 0, index in plane= 10, h=600000.00
#  pos r = 6978000.00, pos theta = 3.14, pos phi = 0.00,
#  pos x= 0.00, pos y= 1043457.63, pos z= -6899542.03
#  inclination = -8.60
#  polar angle = 180.00
#  latitude = -81.40
#  longitude = 90.00
#
# ID = 0_11
#  orbital plane= 0, index in plane= 11, h=600000.00
#  pos r = 6978000.00, pos theta = 3.46, pos phi = 0.00,
#  pos x= -2156320.59, pos y= 992387.18, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 198.00
#  latitude = -70.11
#  longitude = 155.29
#
# ID = 0_12
#  orbital plane= 0, index in plane= 12, h=600000.00
#  pos r = 6978000.00, pos theta = 3.77, pos phi = 0.00,
#  pos x= -4101565.49, pos y= 844174.95, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 216.00
#  latitude = -53.12
#  longitude = 168.37
#
# ID = 0_13
#  orbital plane= 0, index in plane= 13, h=600000.00
#  pos r = 6978000.00, pos theta = 4.08, pos phi = 0.00,
#  pos x= -5645320.59, pos y= 613329.00, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 234.00
#  latitude = -35.53
#  longitude = 173.80
#
# ID = 0_14
#  orbital plane= 0, index in plane= 14, h=600000.00
#  pos r = 6978000.00, pos theta = 4.40, pos phi = 0.00,
#  pos x= -6636472.37, pos y= 322446.14, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 252.00
#  latitude = -17.79
#  longitude = 177.22
#
# ID = 0_15
#  orbital plane= 0, index in plane= 15, h=600000.00
#  pos r = 6978000.00, pos theta = 4.71, pos phi = 0.00,
#  pos x= -6978000.00, pos y= 0.00, pos z= -0.00
#  inclination = -8.60
#  polar angle = 270.00
#  latitude = -0.00
#  longitude = 180.00
#
# ID = 0_16
#  orbital plane= 0, index in plane= 16, h=600000.00
#  pos r = 6978000.00, pos theta = 5.03, pos phi = 0.00,
#  pos x= -6636472.37, pos y= -322446.14, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 288.00
#  latitude = 17.79
#  longitude = -177.22
#
# ID = 0_17
#  orbital plane= 0, index in plane= 17, h=600000.00
#  pos r = 6978000.00, pos theta = 5.34, pos phi = 0.00,
#  pos x= -5645320.59, pos y= -613329.00, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 306.00
#  latitude = 35.53
#  longitude = -173.80
#
# ID = 0_18
#  orbital plane= 0, index in plane= 18, h=600000.00
#  pos r = 6978000.00, pos theta = 5.65, pos phi = 0.00,
#  pos x= -4101565.49, pos y= -844174.95, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 324.00
#  latitude = 53.12
#  longitude = -168.37
#
# ID = 0_19
#  orbital plane= 0, index in plane= 19, h=600000.00
#  pos r = 6978000.00, pos theta = 5.97, pos phi = 0.00,
#  pos x= -2156320.59, pos y= -992387.18, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 342.00
#  latitude = 70.11
#  longitude = -155.29
#
# ID = 1_0
#  orbital plane= 1, index in plane= 0, h=600000.00
#  pos r = 6978000.00, pos theta = 0.00, pos phi = 0.45,
#  pos x= 452739.30, pos y= -940122.84, pos z= 6899542.03
#  inclination = -8.60
#  polar angle = 0.00
#  latitude = 81.40
#  longitude = -64.29
#
# ID = 1_1
#  orbital plane= 1, index in plane= 1, h=600000.00
#  pos r = 6978000.00, pos theta = 0.31, pos phi = 0.45,
#  pos x= 2373358.38, pos y= 41482.49, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 18.00
#  latitude = 70.11
#  longitude = 1.00
#
# ID = 1_2
#  orbital plane= 1, index in plane= 2, h=600000.00
#  pos r = 6978000.00, pos theta = 0.63, pos phi = 0.45,
#  pos x= 4061656.60, pos y= 1019027.22, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 36.00
#  latitude = 53.12
#  longitude = 14.08
#
# ID = 1_3
#  orbital plane= 1, index in plane= 3, h=600000.00
#  pos r = 6978000.00, pos theta = 0.94, pos phi = 0.45,
#  pos x= 5352371.58, pos y= 1896822.47, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 54.00
#  latitude = 35.53
#  longitude = 19.51
#
# ID = 1_4
#  orbital plane= 1, index in plane= 4, h=600000.00
#  pos r = 6978000.00, pos theta = 1.26, pos phi = 0.45,
#  pos x= 6119159.14, pos y= 2588943.51, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 72.00
#  latitude = 17.79
#  longitude = 22.93
#
# ID = 1_5
#  orbital plane= 1, index in plane= 5, h=600000.00
#  pos r = 6978000.00, pos theta = 1.57, pos phi = 0.45,
#  pos x= 6286960.76, pos y= 3027640.73, pos z= 0.00
#  inclination = -8.60
#  polar angle = 90.00
#  latitude = 0.00
#  longitude = 25.71
#
# ID = 1_6
#  orbital plane= 1, index in plane= 6, h=600000.00
#  pos r = 6978000.00, pos theta = 1.88, pos phi = 0.45,
#  pos x= 5839350.86, pos y= 3169971.38, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 108.00
#  latitude = -17.79
#  longitude = 28.50
#
# ID = 1_7
#  orbital plane= 1, index in plane= 7, h=600000.00
#  pos r = 6978000.00, pos theta = 2.20, pos phi = 0.45,
#  pos x= 4820144.62, pos y= 3002003.14, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 126.00
#  latitude = -35.53
#  longitude = 31.91
#
# ID = 1_8
#  orbital plane= 1, index in plane= 8, h=600000.00
#  pos r = 6978000.00, pos theta = 2.51, pos phi = 0.45,
#  pos x= 3329109.03, pos y= 2540177.92, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 144.00
#  latitude = -53.12
#  longitude = 37.34
#
# ID = 1_9
#  orbital plane= 1, index in plane= 9, h=600000.00
#  pos r = 6978000.00, pos theta = 2.83, pos phi = 0.45,
#  pos x= 1512197.06, pos y= 1829702.39, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 162.00
#  latitude = -70.11
#  longitude = 50.43
#
# ID = 1_10
#  orbital plane= 1, index in plane= 10, h=600000.00
#  pos r = 6978000.00, pos theta = 3.14, pos phi = 0.45,
#  pos x= -452739.30, pos y= 940122.84, pos z= -6899542.03
#  inclination = -8.60
#  polar angle = 180.00
#  latitude = -81.40
#  longitude = 115.71
#
# ID = 1_11
#  orbital plane= 1, index in plane= 11, h=600000.00
#  pos r = 6978000.00, pos theta = 3.46, pos phi = 0.45,
#  pos x= -2373358.38, pos y= -41482.49, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 198.00
#  latitude = -70.11
#  longitude = -179.00
#
# ID = 1_12
#  orbital plane= 1, index in plane= 12, h=600000.00
#  pos r = 6978000.00, pos theta = 3.77, pos phi = 0.45,
#  pos x= -4061656.60, pos y= -1019027.22, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 216.00
#  latitude = -53.12
#  longitude = -165.92
#
# ID = 1_13
#  orbital plane= 1, index in plane= 13, h=600000.00
#  pos r = 6978000.00, pos theta = 4.08, pos phi = 0.45,
#  pos x= -5352371.58, pos y= -1896822.47, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 234.00
#  latitude = -35.53
#  longitude = -160.49
#
# ID = 1_14
#  orbital plane= 1, index in plane= 14, h=600000.00
#  pos r = 6978000.00, pos theta = 4.40, pos phi = 0.45,
#  pos x= -6119159.14, pos y= -2588943.51, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 252.00
#  latitude = -17.79
#  longitude = -157.07
#
# ID = 1_15
#  orbital plane= 1, index in plane= 15, h=600000.00
#  pos r = 6978000.00, pos theta = 4.71, pos phi = 0.45,
#  pos x= -6286960.76, pos y= -3027640.73, pos z= -0.00
#  inclination = -8.60
#  polar angle = 270.00
#  latitude = -0.00
#  longitude = -154.29
#
# ID = 1_16
#  orbital plane= 1, index in plane= 16, h=600000.00
#  pos r = 6978000.00, pos theta = 5.03, pos phi = 0.45,
#  pos x= -5839350.86, pos y= -3169971.38, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 288.00
#  latitude = 17.79
#  longitude = -151.50
#
# ID = 1_17
#  orbital plane= 1, index in plane= 17, h=600000.00
#  pos r = 6978000.00, pos theta = 5.34, pos phi = 0.45,
#  pos x= -4820144.62, pos y= -3002003.14, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 306.00
#  latitude = 35.53
#  longitude = -148.09
#
# ID = 1_18
#  orbital plane= 1, index in plane= 18, h=600000.00
#  pos r = 6978000.00, pos theta = 5.65, pos phi = 0.45,
#  pos x= -3329109.03, pos y= -2540177.92, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 324.00
#  latitude = 53.12
#  longitude = -142.66
#
# ID = 1_19
#  orbital plane= 1, index in plane= 19, h=600000.00
#  pos r = 6978000.00, pos theta = 5.97, pos phi = 0.45,
#  pos x= -1512197.06, pos y= -1829702.39, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 342.00
#  latitude = 70.11
#  longitude = -129.57
#
# ID = 2_0
#  orbital plane= 2, index in plane= 0, h=600000.00
#  pos r = 6978000.00, pos theta = 0.00, pos phi = 0.90,
#  pos x= 815808.02, pos y= -650585.19, pos z= 6899542.03
#  inclination = -8.60
#  polar angle = 0.00
#  latitude = 81.40
#  longitude = -38.57
#
# ID = 2_1
#  orbital plane= 2, index in plane= 1, h=600000.00
#  pos r = 6978000.00, pos theta = 0.31, pos phi = 0.90,
#  pos x= 2120323.43, pos y= 1067136.04, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 18.00
#  latitude = 70.11
#  longitude = 26.72
#
# ID = 2_2
#  orbital plane= 2, index in plane= 2, h=600000.00
#  pos r = 6978000.00, pos theta = 0.63, pos phi = 0.90,
#  pos x= 3217286.81, pos y= 2680398.55, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 36.00
#  latitude = 53.12
#  longitude = 39.80
#
# ID = 2_3
#  orbital plane= 2, index in plane= 3, h=600000.00
#  pos r = 6978000.00, pos theta = 0.94, pos phi = 0.90,
#  pos x= 3999319.74, pos y= 4031284.98, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 54.00
#  latitude = 35.53
#  longitude = 45.23
#
# ID = 2_4
#  orbital plane= 2, index in plane= 4, h=600000.00
#  pos r = 6978000.00, pos theta = 1.26, pos phi = 0.90,
#  pos x= 4389871.39, pos y= 4987561.15, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 72.00
#  latitude = 17.79
#  longitude = 48.65
#
# ID = 2_5
#  orbital plane= 2, index in plane= 5, h=600000.00
#  pos r = 6978000.00, pos theta = 1.57, pos phi = 0.90,
#  pos x= 4350711.84, pos y= 5455620.08, pos z= 0.00
#  inclination = -8.60
#  polar angle = 90.00
#  latitude = 0.00
#  longitude = 51.43
#
# ID = 2_6
#  orbital plane= 2, index in plane= 6, h=600000.00
#  pos r = 6978000.00, pos theta = 1.88, pos phi = 0.90,
#  pos x= 3885674.30, pos y= 5389644.91, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 108.00
#  latitude = -17.79
#  longitude = 54.21
#
# ID = 2_7
#  orbital plane= 2, index in plane= 7, h=600000.00
#  pos r = 6978000.00, pos theta = 2.20, pos phi = 0.90,
#  pos x= 3040279.89, pos y= 4796093.74, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 126.00
#  latitude = -35.53
#  longitude = 57.63
#
# ID = 2_8
#  orbital plane= 2, index in plane= 8, h=600000.00
#  pos r = 6978000.00, pos theta = 2.51, pos phi = 0.90,
#  pos x= 1897281.70, pos y= 3733067.50, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 144.00
#  latitude = -53.12
#  longitude = 63.06
#
# ID = 2_9
#  orbital plane= 2, index in plane= 9, h=600000.00
#  pos r = 6978000.00, pos theta = 2.83, pos phi = 0.90,
#  pos x= 568564.36, pos y= 2304622.60, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 162.00
#  latitude = -70.11
#  longitude = 76.14
#
# ID = 2_10
#  orbital plane= 2, index in plane= 10, h=600000.00
#  pos r = 6978000.00, pos theta = 3.14, pos phi = 0.90,
#  pos x= -815808.02, pos y= 650585.19, pos z= -6899542.03
#  inclination = -8.60
#  polar angle = 180.00
#  latitude = -81.40
#  longitude = 141.43
#
# ID = 2_11
#  orbital plane= 2, index in plane= 11, h=600000.00
#  pos r = 6978000.00, pos theta = 3.46, pos phi = 0.90,
#  pos x= -2120323.43, pos y= -1067136.04, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 198.00
#  latitude = -70.11
#  longitude = -153.28
#
# ID = 2_12
#  orbital plane= 2, index in plane= 12, h=600000.00
#  pos r = 6978000.00, pos theta = 3.77, pos phi = 0.90,
#  pos x= -3217286.81, pos y= -2680398.55, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 216.00
#  latitude = -53.12
#  longitude = -140.20
#
# ID = 2_13
#  orbital plane= 2, index in plane= 13, h=600000.00
#  pos r = 6978000.00, pos theta = 4.08, pos phi = 0.90,
#  pos x= -3999319.74, pos y= -4031284.98, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 234.00
#  latitude = -35.53
#  longitude = -134.77
#
# ID = 2_14
#  orbital plane= 2, index in plane= 14, h=600000.00
#  pos r = 6978000.00, pos theta = 4.40, pos phi = 0.90,
#  pos x= -4389871.39, pos y= -4987561.15, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 252.00
#  latitude = -17.79
#  longitude = -131.35
#
# ID = 2_15
#  orbital plane= 2, index in plane= 15, h=600000.00
#  pos r = 6978000.00, pos theta = 4.71, pos phi = 0.90,
#  pos x= -4350711.84, pos y= -5455620.08, pos z= -0.00
#  inclination = -8.60
#  polar angle = 270.00
#  latitude = -0.00
#  longitude = -128.57
#
# ID = 2_16
#  orbital plane= 2, index in plane= 16, h=600000.00
#  pos r = 6978000.00, pos theta = 5.03, pos phi = 0.90,
#  pos x= -3885674.30, pos y= -5389644.91, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 288.00
#  latitude = 17.79
#  longitude = -125.79
#
# ID = 2_17
#  orbital plane= 2, index in plane= 17, h=600000.00
#  pos r = 6978000.00, pos theta = 5.34, pos phi = 0.90,
#  pos x= -3040279.89, pos y= -4796093.74, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 306.00
#  latitude = 35.53
#  longitude = -122.37
#
# ID = 2_18
#  orbital plane= 2, index in plane= 18, h=600000.00
#  pos r = 6978000.00, pos theta = 5.65, pos phi = 0.90,
#  pos x= -1897281.70, pos y= -3733067.50, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 324.00
#  latitude = 53.12
#  longitude = -116.94
#
# ID = 2_19
#  orbital plane= 2, index in plane= 19, h=600000.00
#  pos r = 6978000.00, pos theta = 5.97, pos phi = 0.90,
#  pos x= -568564.36, pos y= -2304622.60, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 342.00
#  latitude = 70.11
#  longitude = -103.86
#
# ID = 3_0
#  orbital plane= 3, index in plane= 0, h=600000.00
#  pos r = 6978000.00, pos theta = 0.00, pos phi = 1.35,
#  pos x= 1017295.97, pos y= -232191.17, pos z= 6899542.03
#  inclination = -8.60
#  polar angle = 0.00
#  latitude = 81.40
#  longitude = -12.86
#
# ID = 3_1
#  orbital plane= 3, index in plane= 1, h=600000.00
#  pos r = 6978000.00, pos theta = 0.31, pos phi = 1.35,
#  pos x= 1447332.43, pos y= 1881430.21, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 18.00
#  latitude = 70.11
#  longitude = 52.43
#
# ID = 3_2
#  orbital plane= 3, index in plane= 2, h=600000.00
#  pos r = 6978000.00, pos theta = 0.63, pos phi = 1.35,
#  pos x= 1735693.91, pos y= 3810884.08, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 36.00
#  latitude = 53.12
#  longitude = 65.51
#
# ID = 3_3
#  orbital plane= 3, index in plane= 3, h=600000.00
#  pos r = 6978000.00, pos theta = 0.94, pos phi = 1.35,
#  pos x= 1854153.58, pos y= 5367302.07, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 54.00
#  latitude = 35.53
#  longitude = 70.94
#
# ID = 3_4
#  orbital plane= 3, index in plane= 4, h=600000.00
#  pos r = 6978000.00, pos theta = 1.26, pos phi = 1.35,
#  pos x= 1791115.77, pos y= 6398331.14, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 72.00
#  latitude = 17.79
#  longitude = 74.36
#
# ID = 3_5
#  orbital plane= 3, index in plane= 5, h=600000.00
#  pos r = 6978000.00, pos theta = 1.57, pos phi = 1.35,
#  pos x= 1552751.08, pos y= 6803046.97, pos z= 0.00
#  inclination = -8.60
#  polar angle = 90.00
#  latitude = 0.00
#  longitude = 77.14
#
# ID = 3_6
#  orbital plane= 3, index in plane= 6, h=600000.00
#  pos r = 6978000.00, pos theta = 1.88, pos phi = 1.35,
#  pos x= 1162392.29, pos y= 6541833.17, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 108.00
#  latitude = -17.79
#  longitude = 79.92
#
# ID = 3_7
#  orbital plane= 3, index in plane= 7, h=600000.00
#  pos r = 6978000.00, pos theta = 2.20, pos phi = 1.35,
#  pos x= 658250.44, pos y= 5640259.16, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 126.00
#  latitude = -35.53
#  longitude = 83.34
#
# ID = 3_8
#  orbital plane= 3, index in plane= 8, h=600000.00
#  pos r = 6978000.00, pos theta = 2.51, pos phi = 1.35,
#  pos x= 89674.46, pos y= 4186577.28, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 144.00
#  latitude = -53.12
#  longitude = 88.77
#
# ID = 3_9
#  orbital plane= 3, index in plane= 9, h=600000.00
#  pos r = 6978000.00, pos theta = 2.83, pos phi = 1.35,
#  pos x= -487679.49, pos y= 2323084.05, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 162.00
#  latitude = -70.11
#  longitude = 101.86
#
# ID = 3_10
#  orbital plane= 3, index in plane= 10, h=600000.00
#  pos r = 6978000.00, pos theta = 3.14, pos phi = 1.35,
#  pos x= -1017295.97, pos y= 232191.17, pos z= -6899542.03
#  inclination = -8.60
#  polar angle = 180.00
#  latitude = -81.40
#  longitude = 167.14
#
# ID = 3_11
#  orbital plane= 3, index in plane= 11, h=600000.00
#  pos r = 6978000.00, pos theta = 3.46, pos phi = 1.35,
#  pos x= -1447332.43, pos y= -1881430.21, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 198.00
#  latitude = -70.11
#  longitude = -127.57
#
# ID = 3_12
#  orbital plane= 3, index in plane= 12, h=600000.00
#  pos r = 6978000.00, pos theta = 3.77, pos phi = 1.35,
#  pos x= -1735693.91, pos y= -3810884.08, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 216.00
#  latitude = -53.12
#  longitude = -114.49
#
# ID = 3_13
#  orbital plane= 3, index in plane= 13, h=600000.00
#  pos r = 6978000.00, pos theta = 4.08, pos phi = 1.35,
#  pos x= -1854153.58, pos y= -5367302.07, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 234.00
#  latitude = -35.53
#  longitude = -109.06
#
# ID = 3_14
#  orbital plane= 3, index in plane= 14, h=600000.00
#  pos r = 6978000.00, pos theta = 4.40, pos phi = 1.35,
#  pos x= -1791115.77, pos y= -6398331.14, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 252.00
#  latitude = -17.79
#  longitude = -105.64
#
# ID = 3_15
#  orbital plane= 3, index in plane= 15, h=600000.00
#  pos r = 6978000.00, pos theta = 4.71, pos phi = 1.35,
#  pos x= -1552751.08, pos y= -6803046.97, pos z= -0.00
#  inclination = -8.60
#  polar angle = 270.00
#  latitude = -0.00
#  longitude = -102.86
#
# ID = 3_16
#  orbital plane= 3, index in plane= 16, h=600000.00
#  pos r = 6978000.00, pos theta = 5.03, pos phi = 1.35,
#  pos x= -1162392.29, pos y= -6541833.17, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 288.00
#  latitude = 17.79
#  longitude = -100.08
#
# ID = 3_17
#  orbital plane= 3, index in plane= 17, h=600000.00
#  pos r = 6978000.00, pos theta = 5.34, pos phi = 1.35,
#  pos x= -658250.44, pos y= -5640259.16, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 306.00
#  latitude = 35.53
#  longitude = -96.66
#
# ID = 3_18
#  orbital plane= 3, index in plane= 18, h=600000.00
#  pos r = 6978000.00, pos theta = 5.65, pos phi = 1.35,
#  pos x= -89674.46, pos y= -4186577.28, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 324.00
#  latitude = 53.12
#  longitude = -91.23
#
# ID = 3_19
#  orbital plane= 3, index in plane= 19, h=600000.00
#  pos r = 6978000.00, pos theta = 5.97, pos phi = 1.35,
#  pos x= 487679.49, pos y= -2323084.05, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 342.00
#  latitude = 70.11
#  longitude = -78.14
#
# ID = 4_0
#  orbital plane= 4, index in plane= 0, h=600000.00
#  pos r = 6978000.00, pos theta = 0.00, pos phi = 1.80,
#  pos x= 1017295.97, pos y= 232191.17, pos z= 6899542.03
#  inclination = -8.60
#  polar angle = 0.00
#  latitude = 81.40
#  longitude = 12.86
#
# ID = 4_1
#  orbital plane= 4, index in plane= 1, h=600000.00
#  pos r = 6978000.00, pos theta = 0.31, pos phi = 1.80,
#  pos x= 487679.49, pos y= 2323084.05, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 18.00
#  latitude = 70.11
#  longitude = 78.14
#
# ID = 4_2
#  orbital plane= 4, index in plane= 2, h=600000.00
#  pos r = 6978000.00, pos theta = 0.63, pos phi = 1.80,
#  pos x= -89674.46, pos y= 4186577.28, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 36.00
#  latitude = 53.12
#  longitude = 91.23
#
# ID = 4_3
#  orbital plane= 4, index in plane= 3, h=600000.00
#  pos r = 6978000.00, pos theta = 0.94, pos phi = 1.80,
#  pos x= -658250.44, pos y= 5640259.16, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 54.00
#  latitude = 35.53
#  longitude = 96.66
#
# ID = 4_4
#  orbital plane= 4, index in plane= 4, h=600000.00
#  pos r = 6978000.00, pos theta = 1.26, pos phi = 1.80,
#  pos x= -1162392.29, pos y= 6541833.17, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 72.00
#  latitude = 17.79
#  longitude = 100.08
#
# ID = 4_5
#  orbital plane= 4, index in plane= 5, h=600000.00
#  pos r = 6978000.00, pos theta = 1.57, pos phi = 1.80,
#  pos x= -1552751.08, pos y= 6803046.97, pos z= 0.00
#  inclination = -8.60
#  polar angle = 90.00
#  latitude = 0.00
#  longitude = 102.86
#
# ID = 4_6
#  orbital plane= 4, index in plane= 6, h=600000.00
#  pos r = 6978000.00, pos theta = 1.88, pos phi = 1.80,
#  pos x= -1791115.77, pos y= 6398331.14, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 108.00
#  latitude = -17.79
#  longitude = 105.64
#
# ID = 4_7
#  orbital plane= 4, index in plane= 7, h=600000.00
#  pos r = 6978000.00, pos theta = 2.20, pos phi = 1.80,
#  pos x= -1854153.58, pos y= 5367302.07, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 126.00
#  latitude = -35.53
#  longitude = 109.06
#
# ID = 4_8
#  orbital plane= 4, index in plane= 8, h=600000.00
#  pos r = 6978000.00, pos theta = 2.51, pos phi = 1.80,
#  pos x= -1735693.91, pos y= 3810884.08, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 144.00
#  latitude = -53.12
#  longitude = 114.49
#
# ID = 4_9
#  orbital plane= 4, index in plane= 9, h=600000.00
#  pos r = 6978000.00, pos theta = 2.83, pos phi = 1.80,
#  pos x= -1447332.43, pos y= 1881430.21, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 162.00
#  latitude = -70.11
#  longitude = 127.57
#
# ID = 4_10
#  orbital plane= 4, index in plane= 10, h=600000.00
#  pos r = 6978000.00, pos theta = 3.14, pos phi = 1.80,
#  pos x= -1017295.97, pos y= -232191.17, pos z= -6899542.03
#  inclination = -8.60
#  polar angle = 180.00
#  latitude = -81.40
#  longitude = -167.14
#
# ID = 4_11
#  orbital plane= 4, index in plane= 11, h=600000.00
#  pos r = 6978000.00, pos theta = 3.46, pos phi = 1.80,
#  pos x= -487679.49, pos y= -2323084.05, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 198.00
#  latitude = -70.11
#  longitude = -101.86
#
# ID = 4_12
#  orbital plane= 4, index in plane= 12, h=600000.00
#  pos r = 6978000.00, pos theta = 3.77, pos phi = 1.80,
#  pos x= 89674.46, pos y= -4186577.28, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 216.00
#  latitude = -53.12
#  longitude = -88.77
#
# ID = 4_13
#  orbital plane= 4, index in plane= 13, h=600000.00
#  pos r = 6978000.00, pos theta = 4.08, pos phi = 1.80,
#  pos x= 658250.44, pos y= -5640259.16, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 234.00
#  latitude = -35.53
#  longitude = -83.34
#
# ID = 4_14
#  orbital plane= 4, index in plane= 14, h=600000.00
#  pos r = 6978000.00, pos theta = 4.40, pos phi = 1.80,
#  pos x= 1162392.29, pos y= -6541833.17, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 252.00
#  latitude = -17.79
#  longitude = -79.92
#
# ID = 4_15
#  orbital plane= 4, index in plane= 15, h=600000.00
#  pos r = 6978000.00, pos theta = 4.71, pos phi = 1.80,
#  pos x= 1552751.08, pos y= -6803046.97, pos z= -0.00
#  inclination = -8.60
#  polar angle = 270.00
#  latitude = -0.00
#  longitude = -77.14
#
# ID = 4_16
#  orbital plane= 4, index in plane= 16, h=600000.00
#  pos r = 6978000.00, pos theta = 5.03, pos phi = 1.80,
#  pos x= 1791115.77, pos y= -6398331.14, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 288.00
#  latitude = 17.79
#  longitude = -74.36
#
# ID = 4_17
#  orbital plane= 4, index in plane= 17, h=600000.00
#  pos r = 6978000.00, pos theta = 5.34, pos phi = 1.80,
#  pos x= 1854153.58, pos y= -5367302.07, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 306.00
#  latitude = 35.53
#  longitude = -70.94
#
# ID = 4_18
#  orbital plane= 4, index in plane= 18, h=600000.00
#  pos r = 6978000.00, pos theta = 5.65, pos phi = 1.80,
#  pos x= 1735693.91, pos y= -3810884.08, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 324.00
#  latitude = 53.12
#  longitude = -65.51
#
# ID = 4_19
#  orbital plane= 4, index in plane= 19, h=600000.00
#  pos r = 6978000.00, pos theta = 5.97, pos phi = 1.80,
#  pos x= 1447332.43, pos y= -1881430.21, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 342.00
#  latitude = 70.11
#  longitude = -52.43
#
# ID = 5_0
#  orbital plane= 5, index in plane= 0, h=600000.00
#  pos r = 6978000.00, pos theta = 0.00, pos phi = 2.24,
#  pos x= 815808.02, pos y= 650585.19, pos z= 6899542.03
#  inclination = -8.60
#  polar angle = 0.00
#  latitude = 81.40
#  longitude = 38.57
#
# ID = 5_1
#  orbital plane= 5, index in plane= 1, h=600000.00
#  pos r = 6978000.00, pos theta = 0.31, pos phi = 2.24,
#  pos x= -568564.36, pos y= 2304622.60, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 18.00
#  latitude = 70.11
#  longitude = 103.86
#
# ID = 5_2
#  orbital plane= 5, index in plane= 2, h=600000.00
#  pos r = 6978000.00, pos theta = 0.63, pos phi = 2.24,
#  pos x= -1897281.70, pos y= 3733067.50, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 36.00
#  latitude = 53.12
#  longitude = 116.94
#
# ID = 5_3
#  orbital plane= 5, index in plane= 3, h=600000.00
#  pos r = 6978000.00, pos theta = 0.94, pos phi = 2.24,
#  pos x= -3040279.89, pos y= 4796093.74, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 54.00
#  latitude = 35.53
#  longitude = 122.37
#
# ID = 5_4
#  orbital plane= 5, index in plane= 4, h=600000.00
#  pos r = 6978000.00, pos theta = 1.26, pos phi = 2.24,
#  pos x= -3885674.30, pos y= 5389644.91, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 72.00
#  latitude = 17.79
#  longitude = 125.79
#
# ID = 5_5
#  orbital plane= 5, index in plane= 5, h=600000.00
#  pos r = 6978000.00, pos theta = 1.57, pos phi = 2.24,
#  pos x= -4350711.84, pos y= 5455620.08, pos z= 0.00
#  inclination = -8.60
#  polar angle = 90.00
#  latitude = 0.00
#  longitude = 128.57
#
# ID = 5_6
#  orbital plane= 5, index in plane= 6, h=600000.00
#  pos r = 6978000.00, pos theta = 1.88, pos phi = 2.24,
#  pos x= -4389871.39, pos y= 4987561.15, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 108.00
#  latitude = -17.79
#  longitude = 131.35
#
# ID = 5_7
#  orbital plane= 5, index in plane= 7, h=600000.00
#  pos r = 6978000.00, pos theta = 2.20, pos phi = 2.24,
#  pos x= -3999319.74, pos y= 4031284.98, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 126.00
#  latitude = -35.53
#  longitude = 134.77
#
# ID = 5_8
#  orbital plane= 5, index in plane= 8, h=600000.00
#  pos r = 6978000.00, pos theta = 2.51, pos phi = 2.24,
#  pos x= -3217286.81, pos y= 2680398.55, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 144.00
#  latitude = -53.12
#  longitude = 140.20
#
# ID = 5_9
#  orbital plane= 5, index in plane= 9, h=600000.00
#  pos r = 6978000.00, pos theta = 2.83, pos phi = 2.24,
#  pos x= -2120323.43, pos y= 1067136.04, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 162.00
#  latitude = -70.11
#  longitude = 153.28
#
# ID = 5_10
#  orbital plane= 5, index in plane= 10, h=600000.00
#  pos r = 6978000.00, pos theta = 3.14, pos phi = 2.24,
#  pos x= -815808.02, pos y= -650585.19, pos z= -6899542.03
#  inclination = -8.60
#  polar angle = 180.00
#  latitude = -81.40
#  longitude = -141.43
#
# ID = 5_11
#  orbital plane= 5, index in plane= 11, h=600000.00
#  pos r = 6978000.00, pos theta = 3.46, pos phi = 2.24,
#  pos x= 568564.36, pos y= -2304622.60, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 198.00
#  latitude = -70.11
#  longitude = -76.14
#
# ID = 5_12
#  orbital plane= 5, index in plane= 12, h=600000.00
#  pos r = 6978000.00, pos theta = 3.77, pos phi = 2.24,
#  pos x= 1897281.70, pos y= -3733067.50, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 216.00
#  latitude = -53.12
#  longitude = -63.06
#
# ID = 5_13
#  orbital plane= 5, index in plane= 13, h=600000.00
#  pos r = 6978000.00, pos theta = 4.08, pos phi = 2.24,
#  pos x= 3040279.89, pos y= -4796093.74, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 234.00
#  latitude = -35.53
#  longitude = -57.63
#
# ID = 5_14
#  orbital plane= 5, index in plane= 14, h=600000.00
#  pos r = 6978000.00, pos theta = 4.40, pos phi = 2.24,
#  pos x= 3885674.30, pos y= -5389644.91, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 252.00
#  latitude = -17.79
#  longitude = -54.21
#
# ID = 5_15
#  orbital plane= 5, index in plane= 15, h=600000.00
#  pos r = 6978000.00, pos theta = 4.71, pos phi = 2.24,
#  pos x= 4350711.84, pos y= -5455620.08, pos z= -0.00
#  inclination = -8.60
#  polar angle = 270.00
#  latitude = -0.00
#  longitude = -51.43
#
# ID = 5_16
#  orbital plane= 5, index in plane= 16, h=600000.00
#  pos r = 6978000.00, pos theta = 5.03, pos phi = 2.24,
#  pos x= 4389871.39, pos y= -4987561.15, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 288.00
#  latitude = 17.79
#  longitude = -48.65
#
# ID = 5_17
#  orbital plane= 5, index in plane= 17, h=600000.00
#  pos r = 6978000.00, pos theta = 5.34, pos phi = 2.24,
#  pos x= 3999319.74, pos y= -4031284.98, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 306.00
#  latitude = 35.53
#  longitude = -45.23
#
# ID = 5_18
#  orbital plane= 5, index in plane= 18, h=600000.00
#  pos r = 6978000.00, pos theta = 5.65, pos phi = 2.24,
#  pos x= 3217286.81, pos y= -2680398.55, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 324.00
#  latitude = 53.12
#  longitude = -39.80
#
# ID = 5_19
#  orbital plane= 5, index in plane= 19, h=600000.00
#  pos r = 6978000.00, pos theta = 5.97, pos phi = 2.24,
#  pos x= 2120323.43, pos y= -1067136.04, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 342.00
#  latitude = 70.11
#  longitude = -26.72
#
# ID = 6_0
#  orbital plane= 6, index in plane= 0, h=600000.00
#  pos r = 6978000.00, pos theta = 0.00, pos phi = 2.69,
#  pos x= 452739.30, pos y= 940122.84, pos z= 6899542.03
#  inclination = -8.60
#  polar angle = 0.00
#  latitude = 81.40
#  longitude = 64.29
#
# ID = 6_1
#  orbital plane= 6, index in plane= 1, h=600000.00
#  pos r = 6978000.00, pos theta = 0.31, pos phi = 2.69,
#  pos x= -1512197.06, pos y= 1829702.39, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 18.00
#  latitude = 70.11
#  longitude = 129.57
#
# ID = 6_2
#  orbital plane= 6, index in plane= 2, h=600000.00
#  pos r = 6978000.00, pos theta = 0.63, pos phi = 2.69,
#  pos x= -3329109.03, pos y= 2540177.92, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 36.00
#  latitude = 53.12
#  longitude = 142.66
#
# ID = 6_3
#  orbital plane= 6, index in plane= 3, h=600000.00
#  pos r = 6978000.00, pos theta = 0.94, pos phi = 2.69,
#  pos x= -4820144.62, pos y= 3002003.14, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 54.00
#  latitude = 35.53
#  longitude = 148.09
#
# ID = 6_4
#  orbital plane= 6, index in plane= 4, h=600000.00
#  pos r = 6978000.00, pos theta = 1.26, pos phi = 2.69,
#  pos x= -5839350.86, pos y= 3169971.38, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 72.00
#  latitude = 17.79
#  longitude = 151.50
#
# ID = 6_5
#  orbital plane= 6, index in plane= 5, h=600000.00
#  pos r = 6978000.00, pos theta = 1.57, pos phi = 2.69,
#  pos x= -6286960.76, pos y= 3027640.73, pos z= 0.00
#  inclination = -8.60
#  polar angle = 90.00
#  latitude = 0.00
#  longitude = 154.29
#
# ID = 6_6
#  orbital plane= 6, index in plane= 6, h=600000.00
#  pos r = 6978000.00, pos theta = 1.88, pos phi = 2.69,
#  pos x= -6119159.14, pos y= 2588943.51, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 108.00
#  latitude = -17.79
#  longitude = 157.07
#
# ID = 6_7
#  orbital plane= 6, index in plane= 7, h=600000.00
#  pos r = 6978000.00, pos theta = 2.20, pos phi = 2.69,
#  pos x= -5352371.58, pos y= 1896822.47, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 126.00
#  latitude = -35.53
#  longitude = 160.49
#
# ID = 6_8
#  orbital plane= 6, index in plane= 8, h=600000.00
#  pos r = 6978000.00, pos theta = 2.51, pos phi = 2.69,
#  pos x= -4061656.60, pos y= 1019027.22, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 144.00
#  latitude = -53.12
#  longitude = 165.92
#
# ID = 6_9
#  orbital plane= 6, index in plane= 9, h=600000.00
#  pos r = 6978000.00, pos theta = 2.83, pos phi = 2.69,
#  pos x= -2373358.38, pos y= 41482.49, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 162.00
#  latitude = -70.11
#  longitude = 179.00
#
# ID = 6_10
#  orbital plane= 6, index in plane= 10, h=600000.00
#  pos r = 6978000.00, pos theta = 3.14, pos phi = 2.69,
#  pos x= -452739.30, pos y= -940122.84, pos z= -6899542.03
#  inclination = -8.60
#  polar angle = 180.00
#  latitude = -81.40
#  longitude = -115.71
#
# ID = 6_11
#  orbital plane= 6, index in plane= 11, h=600000.00
#  pos r = 6978000.00, pos theta = 3.46, pos phi = 2.69,
#  pos x= 1512197.06, pos y= -1829702.39, pos z= -6561854.40
#  inclination = -8.60
#  polar angle = 198.00
#  latitude = -70.11
#  longitude = -50.43
#
# ID = 6_12
#  orbital plane= 6, index in plane= 12, h=600000.00
#  pos r = 6978000.00, pos theta = 3.77, pos phi = 2.69,
#  pos x= 3329109.03, pos y= -2540177.92, pos z= -5581846.75
#  inclination = -8.60
#  polar angle = 216.00
#  latitude = -53.12
#  longitude = -37.34
#
# ID = 6_13
#  orbital plane= 6, index in plane= 13, h=600000.00
#  pos r = 6978000.00, pos theta = 4.08, pos phi = 2.69,
#  pos x= 4820144.62, pos y= -3002003.14, pos z= -4055449.05
#  inclination = -8.60
#  polar angle = 234.00
#  latitude = -35.53
#  longitude = -31.91
#
# ID = 6_14
#  orbital plane= 6, index in plane= 14, h=600000.00
#  pos r = 6978000.00, pos theta = 4.40, pos phi = 2.69,
#  pos x= 5839350.86, pos y= -3169971.38, pos z= -2132075.74
#  inclination = -8.60
#  polar angle = 252.00
#  latitude = -17.79
#  longitude = -28.50
#
# ID = 6_15
#  orbital plane= 6, index in plane= 15, h=600000.00
#  pos r = 6978000.00, pos theta = 4.71, pos phi = 2.69,
#  pos x= 6286960.76, pos y= -3027640.73, pos z= -0.00
#  inclination = -8.60
#  polar angle = 270.00
#  latitude = -0.00
#  longitude = -25.71
#
# ID = 6_16
#  orbital plane= 6, index in plane= 16, h=600000.00
#  pos r = 6978000.00, pos theta = 5.03, pos phi = 2.69,
#  pos x= 6119159.14, pos y= -2588943.51, pos z= 2132075.74
#  inclination = -8.60
#  polar angle = 288.00
#  latitude = 17.79
#  longitude = -22.93
#
# ID = 6_17
#  orbital plane= 6, index in plane= 17, h=600000.00
#  pos r = 6978000.00, pos theta = 5.34, pos phi = 2.69,
#  pos x= 5352371.58, pos y= -1896822.47, pos z= 4055449.05
#  inclination = -8.60
#  polar angle = 306.00
#  latitude = 35.53
#  longitude = -19.51
#
# ID = 6_18
#  orbital plane= 6, index in plane= 18, h=600000.00
#  pos r = 6978000.00, pos theta = 5.65, pos phi = 2.69,
#  pos x= 4061656.60, pos y= -1019027.22, pos z= 5581846.75
#  inclination = -8.60
#  polar angle = 324.00
#  latitude = 53.12
#  longitude = -14.08
#
# ID = 6_19
#  orbital plane= 6, index in plane= 19, h=600000.00
#  pos r = 6978000.00, pos theta = 5.97, pos phi = 2.69,
#  pos x= 2373358.38, pos y= -41482.49, pos z= 6561854.40
#  inclination = -8.60
#  polar angle = 342.00
#  latitude = 70.11
#  longitude = -1.00
# Location = Malaga, Spain
#  Longitude = -4.41
#  Latitude = 36.72
#  pos x= 5097258.204421738, pos y= -393107.5620566591, pos z= 3813437.9819408567
# Location = Los Angeles, California, US
#  Longitude = -118.24
#  Latitude = 34.05
#  pos x= -2500439.24220534, pos y= -4655492.34415103, pos z= 3571145.2826216323
# Location = Aalborg, Denmark
#  Longitude = 9.98
#  Latitude = 57.01
#  pos x= 3420225.178995899, pos y= 601847.0517727446, pos z= 5349647.077259857
# Location = Cordoba, Argentina (partner station)
#  Longitude = -63.79
#  Latitude = -32.09
#  pos x= 2386538.522413902, pos y= -4847950.611468634, pos z= -3388317.096995995
# Location = Tolhuin, Argentina (partner station)
#  Longitude = -67.19
#  Latitude = -54.51
#  pos x= 1435495.1022556564, pos y= -3413240.194182917, pos z= -5193075.118676234
# Location = Inuvik, Northwest Territories, Canada
#  Longitude = -133.72
#  Latitude = 68.36
#  pos x= -1625575.0323917929, pos y= -1699878.7445357067, pos z= 5928473.839694339
# Location = Nemea, Greece
#  Longitude = 22.66
#  Latitude = 37.82
#  pos x= 4649328.065848175, pos y= 1941043.3632849536, pos z= 3910880.1052913773
# Location = Nuuk, Greenland
#  Longitude = -51.73
#  Latitude = 64.17
#  pos x= 1721168.1592544324, pos y= -2181724.5593008515, pos z= 5740778.877026376
# Location = Bangalore, India (partner station)
#  Longitude = 77.59
#  Latitude = 12.97
#  pos x= 1335700.1987914785, pos y= 6070061.233357082, pos z= 1431483.7065939326
# Location = Tokyo, Japan
#  Longitude = 139.75
#  Latitude = 35.68
#  pos x= -3954130.036400788, pos y= 3347418.1671975, pos z= 3720017.643661013
# Location = Mauritius
#  Longitude = 57.57
#  Latitude = -20.27
#  pos x= 3208503.4802394235, pos y= 5049946.016967264, pos z= -2209623.1902765613
# Location = Awarua, New Zealand
#  Longitude = 168.36
#  Latitude = -46.5
#  pos x= -4300036.824662693, pos y= 885799.7290736338, pos z= -4626437.738316367
# Location = Svalbard, Norway
#  Longitude = 15.99
#  Latitude = 78.33
#  pos x= 1240192.5508899419, pos y= 355385.25119217037, pos z= 6246159.44080458
# Location = Vardø, Norway
#  Longitude = 30.96
#  Latitude = 70.33
#  pos x= 1840980.4248618805, pos y= 1104424.1069667125, pos z= 6005824.045643208
# Location = Azores, Portugal (partner station)
#  Longitude = -25.47
#  Latitude = 37.8
#  pos x= 4549812.003692749, pos y= -2167225.4767396683, pos z= 3909121.1881986833
# Location = Singapore
#  Longitude = 103.83
#  Latitude = 1.34
#  pos x= -1524192.3597247086, pos y= 6191403.357523117, pos z= 149151.31581147257
# Location = Hawaii, US
#  Longitude = -155.42
#  Latitude = 19.58
#  pos x= -5464644.390691152, pos y= -2499602.5467686574, pos z= 2137412.639495557
# Location = Jeju, South Korea
#  Longitude = 126.53
#  Latitude = 33.38
#  pos x= -3170198.9240592774, pos y= 4279589.794871565, pos z= 3509107.2895431053

# %%
nx.__version__

# %%
dir(earth1.LEO[0].sats[0])
